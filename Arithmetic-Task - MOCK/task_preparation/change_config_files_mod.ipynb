# %%
import os, pandas as pd, numpy as np, shutil; from glob import glob

#Assign work_dir
work_dir = os.path.join(os.path.dirname(os.getcwd()),"config"); os.chdir(work_dir)
#Gather config files
files = glob("./*.tsv"); length = [pd.read_csv(file, sep = "\t").shape[0] for file in files]
# Make new directories
os.makedirs("english"); os.makedirs("spanish")
#Copy and move fils
[shutil.copy(file,".\\english" + file) for file in files]
[os.rename(file, ".\\spanish" + file) for file in files]
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
#Replace word trials with english_word
for file in glob(".\\english\\*.tsv"):
    df = pd.read_csv(file, sep="\t")
    df.equation_representation = [x.replace("word", "english_word") if x == "word" else x for x in df.equation_representation]
    df.comparison_representation = [x.replace("word", "english_word") if x == "word" else x for x in df.comparison_representation]
    df.to_csv(file, sep="\t",index=False)

# %%
for file in glob(".\\spanish\\*.tsv"):
    df = pd.read_csv(file, sep="\t")
    counts = [3,3,3,3,2,2,3,3,2]
    pairs = ["english_word numeric", "numeric english_word", "spanish_word numeric", "numeric spanish_word", "english_word english_word", "spanish_word spanish_word", "english_word spanish_word","spanish_word english_word", "numeric numeric"]
    combos = np.random.choice([pair for sublist in [[x]*y for x,y in zip(pairs,counts)] for pair in sublist], size = 24, replace=False)
    df.equation_representation, df.comparison_representation = [x.split(" ")[0] for x in combos], [x.split(" ")[1] for x in combos]
    df.to_csv(file, sep="\t",index=False)

# %%
import numpy as np
counts = [3,3,3,3,2,2,3,3,2]

#np.sum(np.array([x/24 for x in counts]))
[x/24 for x in counts]
# Out:
# [0.125,
#  0.125,
#  0.125,
#  0.125,
#  0.08333333333333333,
#  0.08333333333333333,
#  0.125,
#  0.125,
#  0.08333333333333333]

# %%
import os, pandas as pd, numpy as np, shutil; from glob import glob
work_dir = os.path.join(os.path.dirname(os.getcwd()),"config"); os.chdir(work_dir)
work_dir
# Out:
# 'c:\\Users\\donis\\OneDrive\\Desktop\\Arithmetic-Task - MOCK\\config'

# %%
for file in glob(".\\spanish\\*.tsv"):
    df = pd.read_csv(file, sep="\t")
    counts = [8,8,8]
    pairs = ["spanish_word spanish_word", "english_word english_word", "numeric numeric"]
    combos = np.random.choice([pair for sublist in [[x]*y for x,y in zip(pairs,counts)] for pair in sublist], size = 24, replace=False)
    df.equation_representation, df.comparison_representation = [x.split(" ")[0] for x in combos], [x.split(" ")[1] for x in combos]
    df.to_csv(file, sep="\t",index=False)

# %%
for file in glob(".\\english\\*.tsv"):
    df = pd.read_csv(file, sep="\t")
    counts = [12,12]
    pairs = ["english_word english_word", "numeric numeric"]
    combos = np.random.choice([pair for sublist in [[x]*y for x,y in zip(pairs,counts)] for pair in sublist], size = 24, replace=False)
    df.equation_representation, df.comparison_representation = [x.split(" ")[0] for x in combos], [x.split(" ")[1] for x in combos]
    df.to_csv(file, sep="\t",index=False)

# %%
counts = [12,12]
pairs = ["english_word english_word", "numeric numeric"]
combos = np.random.choice([pair for sublist in [[x]*y for x,y in zip(pairs,counts)] for pair in sublist], size = 24, replace=False)
combos
# Out:
# array(['english_word english_word', 'numeric numeric', 'numeric numeric',
#        'numeric numeric', 'english_word english_word',
#        'english_word english_word', 'numeric numeric', 'numeric numeric',
#        'numeric numeric', 'english_word english_word', 'numeric numeric',
#        'numeric numeric', 'english_word english_word', 'numeric numeric',
#        'english_word english_word', 'numeric numeric',
#        'english_word english_word', 'english_word english_word',
#        'english_word english_word', 'english_word english_word',
#        'english_word english_word', 'numeric numeric', 'numeric numeric',
#        'english_word english_word'], dtype='<U25')

# %%
# Change extensions of word files
work_dir = os.path.join(os.path.dirname(os.getcwd()),"stimuli","numerals"); os.chdir(work_dir)
[os.rename(x, x.replace("_w","_e")) for x in glob(".\\english\\*")]
[os.rename(x, x.replace("_w","_s")) for x in glob(".\\spanish\\*")]
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ...]

# %%
x = []
for file in glob(".\\spanish\\*.tsv"):
    df = pd.read_csv(file, sep = "\t")
    if list(df.equation_representation.value_counts()) + list(df.comparison_representation.value_counts()) != [8]*6:
        x.append(False)
    else: x.append(True)

all(x)
# Out:
# True

# %%
df = pd.read_csv('C:\\Users\\donis\\OneDrive\\Desktop\\Arithmetic-Task - MOCK\\config\\english\\config_00144.tsv', sep = "\t")

df[["equation_representation","comparison_representation"]]
# Out:
#    equation_representation comparison_representation
# 0                  numeric                   numeric
# 1                  numeric                   numeric
# 2             english_word              english_word
# 3             english_word              english_word
# 4                  numeric                   numeric
# 5             english_word              english_word
# 6             english_word              english_word
# 7                  numeric                   numeric
# 8             english_word              english_word
# 9             english_word              english_word
# 10            english_word              english_word
# 11            english_word              english_word
# 12            english_word              english_word
# 13                 numeric                   numeric
# 14                 numeric                   numeric
# 15                 numeric                   numeric
# 16                 numeric                   numeric
# 17            english_word              english_word
# 18                 numeric                   numeric
# 19                 numeric                   numeric
# 20                 numeric                   numeric
# 21            english_word              english_word
# 22                 numeric                   numeric
# 23            english_word              english_word

# %%
import os, pandas as pd, numpy as np, shutil; from glob import glob

work_dir = os.path.join(os.path.dirname(os.getcwd()),"config"); os.chdir(work_dir)
work_dir

[8,8]
for file in glob(".\\spanish\\*.tsv"):
    df = pd.read_csv(file, sep="\t")

# %%
check_list = []
for file in glob(".\\spanish\\*.tsv"):
    df = pd.read_csv(file, sep="\t")
    z = [x + " " + y for x,y in [[x,y] for x,y in zip(df.equation_representation, df.comparison_representation)]]
    df["new_col"] = z
    check_list.append(list(df.new_col.value_counts()))

# %%
check_list = []
for file in glob(".\\english\\*.tsv"):
    df = pd.read_csv(file, sep="\t")
    z = [[x,y] for x,y in zip(df.equation_representation, df.comparison_representation)][0]
    check_list.append(z)

# %%
all([x == y for x,y in check_list])
# Out:
# True

# %%
check_list = []
for file in glob(".\\english\\*.tsv"):
    df = pd.read_csv(file, sep="\t")
    z = [x + " " + y for x,y in [[x,y] for x,y in zip(df.equation_representation, df.comparison_representation)]]
    df["new_col"] = z
    check_list.append(list(df.new_col.value_counts()))

# %%
#Modify training config files
import os, pandas as pd, numpy as np, shutil; from glob import glob

#Assign work_dir
work_dir = os.path.join(os.path.dirname(os.getcwd()),"config"); os.chdir(work_dir)

file = glob(".\\english\\*.tsv")
file
#df = pd.read_csv(file, sep="\t")
# Out:
# 'c:\\Users\\donis\\OneDrive\\Desktop\\Arithmetic-Task - MOCK\\config'
